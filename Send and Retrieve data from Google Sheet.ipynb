# %% [markdown]
# # Import all necessary Librries

# %%
from df2gspread import gspread2df as g2d

# %%
from df2gspread import df2gspread as d2g

# %%
import pandas as pd

# %%
import numpy as np

# %%
import gspread

# %%
from oauth2client.service_account import ServiceAccountCredentials

# %% [markdown]
# # Scope with credentials for to give authorize

# %%
scope = ['https://www.googleapis.com/auth/drive']

# %%
credentials =ServiceAccountCredentials.from_json_keyfile_name('Desktop/Login-4398ac0aa1d7.json',
                                                           scope
                                                          )

# %%
gc = gspread.authorize(credentials)

# %% [markdown]
# # Pass sheet ID & Data

# %%
# Pass your google sheet id
spreadsheet_key = '1pkLRWSXivHrNWQDBvBHBLtljCOtM03D3fjrYe-bVATg'

# %%
d = pd.read_excel('Desktop/ps.xlsx')

# %%
df = pd.DataFrame(d)
df.replace(np.nan, '', inplace=True)

# %%
wks_name = 'Sheet1'
cell_of_start_df = 'A1'

# %% [markdown]
# # Upload data to google sheet

# %%
d2g.upload(df,
       spreadsheet_key,
       wks_name,
       credentials=credentials,
       col_names=True,
       row_names=False,
       start_cell = cell_of_start_df)
print ('Successfully updated')
# Out:
# Successfully updated

# %% [markdown]
# # Download data from google sheet

# %%
data = g2d.download(
       spreadsheet_key,
       wks_name,
       credentials=credentials,
       col_names=True,
       row_names=False,
       start_cell = cell_of_start_df)
print ('Successfully updated')
# Out:
# Successfully updated

# %%
data
# Out:
#      Row ID Order Priority Discount Unit Price Shipping Cost Customer ID  \
# 0     20847           High     0.01       2.84          0.93           3
# 1     20228  Not Specified     0.02     500.98          26.0           5
# 2     21776       Critical     0.06       9.48          7.29          11
# 3     24844         Medium     0.09      78.69         19.99          14
# 4     24846         Medium     0.08       3.28          2.31          14
# 5     24847         Medium     0.05       3.28           4.2          14
# 6     24848         Medium     0.05       3.58          1.63          14
# 7     18181       Critical      0.0       4.42          4.99          15
# 8     20925         Medium     0.01      35.94          6.66          15
# 9     26267           High     0.04       2.98          1.58          16
# 10    26268           High     0.05     115.99           2.5          16
# 11    23890           High     0.05      26.48          6.93          18
# ...
